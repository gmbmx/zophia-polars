# %%
import polars as pl
import pandas as pd

# %% [markdown]
# ## Requisitos
#
# ### Datasets
# Para realizar estos ejercicios hay que descargar el dataset de Taxis de NYC:<br>
# https://data.cityofnewyork.us/Transportation/2018-Yellow-Taxi-Trip-Data/t29m-gskq
# <br><br>
#
# También es posible descargar los parquets:
# <br>https://www.nyc.gov/site/tlc/about/tlc-trip-record-data.page
# <br><br>
#
# Finalmente también hay un dataset en Kaggle:<br>
# https://www.kaggle.com/c/nyc-taxi-trip-duration
#
# ### Packages
#
# - pyarrow
# - connectorx
# - psycopg2-binary
# - SQLAlchemy
# - python-dotenv
# - plotly
# - matplotlib
#
# ### Base de Datos
#
# - Postgres
#
# ### Cuentas
#
# - Cuenta gratuita en https://www.mapbox.com/

# %% [markdown]
# ## CSV
# Podemos leer muestras tanto con Pandascomo con Polars 🐻‍❄️.

# %%
sample = pd.read_csv('../data/Taxi_Trip_Data.csv',nrows=10)
sample
# Out:
#    VendorID    tpep_pickup_datetime   tpep_dropoff_datetime  passenger_count  \
# 0         1  11/13/2018 07:45:26 AM  11/13/2018 07:57:39 AM                1
# 1         2  11/13/2018 07:24:47 AM  11/13/2018 07:29:45 AM                1
# 2         2  11/13/2018 07:31:34 AM  11/13/2018 07:36:04 AM                1
# 3         2  11/13/2018 07:36:59 AM  11/13/2018 07:51:07 AM                1
# 4         2  11/13/2018 07:53:40 AM  11/13/2018 08:21:53 AM                1
# 5         2  11/13/2018 07:26:53 AM  11/13/2018 07:30:55 AM                1
# 6         2  11/13/2018 07:44:07 AM  11/13/2018 08:24:08 AM                2
# 7         4  11/13/2018 07:11:46 AM  11/13/2018 07:23:47 AM                1
# 8         4  11/13/2018 07:26:25 AM  11/13/2018 07:29:20 AM                1
# 9         4  11/13/2018 07:34:29 AM  11/13/2018 07:46:43 AM                1
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# ...

# %%
pl_sample = pl.read_csv('../data/Taxi_Trip_Data.csv',n_rows=10)
pl_sample
# Out:
# shape: (10, 17)
# ┌──────────┬────────────┬────────────┬────────────┬─────┬──────────┬────────────┬────────────┬────────────┐
# │ VendorID ┆ tpep_picku ┆ tpep_dropo ┆ passenger_ ┆ ... ┆ tip_amou ┆ tolls_amou ┆ improvemen ┆ total_amou │
# │ ---      ┆ p_datetime ┆ ff_datetim ┆ count      ┆     ┆ nt       ┆ nt         ┆ t_surcharg ┆ nt         │
# │ i64      ┆ ---        ┆ e          ┆ ---        ┆     ┆ ---      ┆ ---        ┆ e          ┆ ---        │
# │          ┆ str        ┆ ---        ┆ i64        ┆     ┆ f64      ┆ f64        ┆ ---        ┆ f64        │
# │          ┆            ┆ str        ┆            ┆     ┆          ┆            ┆ f64        ┆            │
# ╞══════════╪════════════╪════════════╪════════════╪═════╪══════════╪════════════╪════════════╪════════════╡
# │ 1        ┆ 11/13/2018 ┆ 11/13/2018 ┆ 1          ┆ ... ┆ 1.0      ┆ 0.0        ┆ 0.3        ┆ 11.3       │
# ...

# %% [markdown]
# ## Parquet
# Formato columnar con compresión ampliamente usado en todas las arquitecturas analíticas de datos
#
# ![parquet](../img/parquet.gif)
#
# Fuente y mayor detalle: https://parquet.apache.org/docs/

# %% [markdown]
# Leamos el CSV y escribamos a Parquet. Polars 🐻‍❄️ de momento no puede escribir directamente particionando por alguna columna y genera un único archivo

# %%
taxi_df = pl.scan_csv('../data/Taxi_Trip_Data.csv',infer_schema_length=0)
taxi_df.sink_parquet(
        "../output/taxi.parquet",
        compression="snappy",
        
        row_group_size=1_000_000)

# %% [markdown]
# Podemos apoyarnos de Arrow 🏹 para obtener la metadata

# %%
import pyarrow.parquet as pq
parquet_file = pq.ParquetFile('../output/taxi.parquet')
parquet_file.metadata
# Out:
# ...
#   created_by: Arrow2 - Native Rust implementation of Arrow
#   num_columns: 17
#   num_rows: 112234626
#   num_row_groups: 3980
#   format_version: 2.6
#   serialized_size: 4084593

# %% [markdown]
# También es posible acceder directamente con `read_metadata`

# %%
pq.read_metadata('../output/taxi.parquet')
# Out:
# ...
#   created_by: Arrow2 - Native Rust implementation of Arrow
#   num_columns: 17
#   num_rows: 112234626
#   num_row_groups: 3980
#   format_version: 2.6
#   serialized_size: 4084593

# %% [markdown]
# Podemos ir explorando 🔍 los `row groups` y cada columna

# %%
parquet_file.metadata.row_group(0)
# Out:
# ...
#   num_columns: 17
#   num_rows: 27774
#   total_byte_size: 4045407

# %%
parquet_file.metadata.row_group(0).column(0)
# Out:
# ...
#   file_offset: 23436
#   file_path:
#   physical_type: BYTE_ARRAY
#   num_values: 27774
#   path_in_schema: VendorID
#   is_stats_set: False
#   statistics:
#     None
#   compression: SNAPPY
#   encodings: ('PLAIN', 'RLE')
#   has_dictionary_page: False
#   dictionary_page_offset: None
#   data_page_offset: 4
#   total_compressed_size: 23432
#   total_uncompressed_size: 142375

# %%
taxi_df.schema
# Out:
# {'VendorID': Utf8,
#  'tpep_pickup_datetime': Utf8,
#  'tpep_dropoff_datetime': Utf8,
#  'passenger_count': Utf8,
#  'trip_distance': Utf8,
#  'RatecodeID': Utf8,
#  'store_and_fwd_flag': Utf8,
#  'PULocationID': Utf8,
#  'DOLocationID': Utf8,
#  'payment_type': Utf8,
#  'fare_amount': Utf8,
#  'extra': Utf8,
#  'mta_tax': Utf8,
#  'tip_amount': Utf8,
#  'tolls_amount': Utf8,
#  'improvement_surcharge': Utf8,
#  'total_amount': Utf8}

# %% [markdown]
# 🐻‍❄️ Podemos obtener directamente el Schema del Parquet

# %%
schema = pl.read_parquet_schema('../output/taxi.parquet')
schema
# Out:
# {'VendorID': Utf8,
#  'tpep_pickup_datetime': Utf8,
#  'tpep_dropoff_datetime': Utf8,
#  'passenger_count': Utf8,
#  'trip_distance': Utf8,
#  'RatecodeID': Utf8,
#  'store_and_fwd_flag': Utf8,
#  'PULocationID': Utf8,
#  'DOLocationID': Utf8,
#  'payment_type': Utf8,
#  'fare_amount': Utf8,
#  'extra': Utf8,
#  'mta_tax': Utf8,
#  'tip_amount': Utf8,
#  'tolls_amount': Utf8,
#  'improvement_surcharge': Utf8,
#  'total_amount': Utf8}

# %% [markdown]
# A pesar de no contar con particiones, la lectura y ejecución de operaciones en Parquet es muy veloz 🚀

# %%
taxi_total_amount = pl.scan_parquet('../output/taxi.parquet') \
    .select(
        pl.col("total_amount").cast(pl.Float64)
    ) \
    .sum() \
    .collect()    
    
taxi_total_amount
# Out:
# shape: (1, 1)
# ┌──────────────┐
# │ total_amount │
# │ ---          │
# │ f64          │
# ╞══════════════╡
# │ 1.8379e9     │
# └──────────────┘

# %%
pl.scan_parquet('../output/taxi.parquet').collect().shape
# Out:
# (112234626, 17)

# %% [markdown]
# Debido al formato columnar, si operamos en varias columnas el tiempo 🕒 aumenta:

# %%
pl.scan_parquet('../output/taxi.parquet') \
    .select(
        (
            pl.col("total_amount").cast(pl.Float64) - pl.col("tip_amount").cast(pl.Float64)
        ).alias("tolls_amount2")
    ) \
    .sum() \
    .collect()
# Out:
# shape: (1, 1)
# ┌───────────────┐
# │ tolls_amount2 │
# │ ---           │
# │ f64           │
# ╞═══════════════╡
# │ 1.6277e9      │
# └───────────────┘

# %% [markdown]
# ## Pyarrow 🏹
#
# ¿Cómo podemos usar mejor las ventajas de Parquet? Con Pyarrow

# %%
import pyarrow.dataset as ds
arrow_ds = ds.dataset('../output/taxi.parquet')
lazy_df = pl.scan_ds(arrow_ds)
lazy_df.select(pl.count("VendorID")).collect()
# Out:
# shape: (1, 1)
# ┌───────────┐
# │ VendorID  │
# │ ---       │
# │ u32       │
# ╞═══════════╡
# │ 112234626 │
# └───────────┘

# %% [markdown]
# No importa de dónde provenga la fuente, una vez que tenemos la referencia en Polars en un lazy dataframe, el performance es similar

# %%
lazy_df.select(
        (
            pl.col("total_amount").cast(pl.Float64) - pl.col("tip_amount").cast(pl.Float64)
        ).alias("tolls_amount2")
    ) \
    .sum() \
    .collect()
# Out:
# shape: (1, 1)
# ┌───────────────┐
# │ tolls_amount2 │
# │ ---           │
# │ f64           │
# ╞═══════════════╡
# │ 1.6277e9      │
# └───────────────┘

# %% [markdown]
# Por el momento los datasets de Arrow 🏹 tienen problemas en aplicar algunas operaciones normales en dataframes:

# %%
lazy_df.first().collect()
# Out:
# shape: (1, 17)
# ┌──────────┬────────────┬────────────┬────────────┬─────┬──────────┬────────────┬────────────┬────────────┐
# │ VendorID ┆ tpep_picku ┆ tpep_dropo ┆ passenger_ ┆ ... ┆ tip_amou ┆ tolls_amou ┆ improvemen ┆ total_amou │
# │ ---      ┆ p_datetime ┆ ff_datetim ┆ count      ┆     ┆ nt       ┆ nt         ┆ t_surcharg ┆ nt         │
# │ str      ┆ ---        ┆ e          ┆ ---        ┆     ┆ ---      ┆ ---        ┆ e          ┆ ---        │
# │          ┆ str        ┆ ---        ┆ str        ┆     ┆ str      ┆ str        ┆ ---        ┆ str        │
# │          ┆            ┆ str        ┆            ┆     ┆          ┆            ┆ str        ┆            │
# ╞══════════╪════════════╪════════════╪════════════╪═════╪══════════╪════════════╪════════════╪════════════╡
# │ 1        ┆ 11/13/2018 ┆ 11/13/2018 ┆ 1          ┆ ... ┆ 1        ┆ 0          ┆ 0.3        ┆ 11.3       │
# ...

# %% [markdown]
# Antes de realizar una transformación costosa, vamos a validar su funcionamiento en una muestra

# %%
taxi_sample_df = pl_sample.with_columns([
    (pl.col("tpep_pickup_datetime").str.slice(6,4)
    +
    pl.col("tpep_pickup_datetime").str.slice(0,2))
    .cast(pl.Int32)
    .alias('date')
])
taxi_sample_df
# Out:
# shape: (10, 18)
# ┌──────────┬────────────┬────────────┬────────────┬─────┬────────────┬────────────┬────────────┬────────┐
# │ VendorID ┆ tpep_picku ┆ tpep_dropo ┆ passenger_ ┆ ... ┆ tolls_amou ┆ improvemen ┆ total_amou ┆ date   │
# │ ---      ┆ p_datetime ┆ ff_datetim ┆ count      ┆     ┆ nt         ┆ t_surcharg ┆ nt         ┆ ---    │
# │ i64      ┆ ---        ┆ e          ┆ ---        ┆     ┆ ---        ┆ e          ┆ ---        ┆ i32    │
# │          ┆ str        ┆ ---        ┆ i64        ┆     ┆ f64        ┆ ---        ┆ f64        ┆        │
# │          ┆            ┆ str        ┆            ┆     ┆            ┆ f64        ┆            ┆        │
# ╞══════════╪════════════╪════════════╪════════════╪═════╪════════════╪════════════╪════════════╪════════╡
# │ 1        ┆ 11/13/2018 ┆ 11/13/2018 ┆ 1          ┆ ... ┆ 0.0        ┆ 0.3        ┆ 11.3       ┆ 201811 │
# │          ┆ 07:45:26   ┆ 07:57:39   ┆            ┆     ┆            ┆            ┆            ┆        │
# ...

# %%
taxi_lazy_df = lazy_df.with_columns(
    (pl.col("tpep_pickup_datetime").str.slice(6,4)
    +
    pl.col("tpep_pickup_datetime").str.slice(0,2))
    .cast(pl.Int32)
    .alias('date')
).collect()

# %% [markdown]
# Ahora vamos a escribir con arrow un parquet con particiones.

# %%
taxi_arrow = taxi_lazy_df.to_arrow()
pq.write_to_dataset(taxi_arrow, root_path ='../output/taxi_par/', partition_cols =['date'], compression= "SNAPPY")

# %% [markdown]
# 🐻‍❄️ Polars **NO** puede leer varias particiones directamente

# %%
pl.read_parquet('../output/taxi_par/').head()
# Out:
# ---------------------------------------------------------------------------
# IsADirectoryError                         Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 pl.read_parquet('../output/taxi_par/').head()
#
# File ~/Zophia/zophia-polars/zophia-polars/.conda/lib/python3.10/site-packages/polars/utils.py:531, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     529 if len(args) > num_allowed_args:
#     530     warnings.warn(msg, DeprecationWarning, stacklevel=2)
# --> 531 return function(*args, **kwargs)
#
# File ~/Zophia/zophia-polars/zophia-polars/.conda/lib/python3.10/site-packages/polars/io/parquet.py:164, in read_parquet(source, columns, n_rows, use_pyarrow, memory_map, storage_options, parallel, row_count_name, row_count_offset, low_memory, pyarrow_options, use_statistics, rechunk)
#     161 storage_options = storage_options or {}
#     162 pyarrow_options = pyarrow_options or {}
# --> 164 with _prepare_file_arg(
# ...

# %% [markdown]
# Para lograrlo nos apoyamos en Pyarrow 🏹

# %%
taxi_partitioned_ds = ds.dataset('../output/taxi_par/')
lazy_partition_df = pl.scan_ds(taxi_partitioned_ds)

# %% [markdown]
# Comparemos tiempos de lectura

# %%
# %%timeit
lazy_partition_df.select(pl.count("VendorID")).collect()
# Out:
# 2.29 s ± 51.8 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %%timeit
arrow_ds = ds.dataset('../output/taxi.parquet')
lazy_df = pl.scan_ds(arrow_ds)
lazy_df.select(pl.count("VendorID")).collect()
# Out:
# 434 ms ± 15.8 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# ## JSON

# %%
with open('../data/censo.csv', 'r', encoding='latin1') as fh:
    polars_df = pl.read_csv(fh.read().encode('utf-8'))
polars_df.write_json('../output/censo.json')

# %%
polars_df.write_ndjson('../output/censo_nd.json')

# %%
censo_df = pl.read_json('../output/censo.json')
censo_df.head()
# Out:
# shape: (5, 198)
# ┌─────────┬──────────┬─────┬─────────────────────┬─────┬─────────┬───────────┬─────────┬───────────┐
# │ ENTIDAD ┆ NOM_ENT  ┆ MUN ┆ NOM_MUN             ┆ ... ┆ VPH_PC  ┆ VPH_TELEF ┆ VPH_CEL ┆ VPH_INTER │
# │ ---     ┆ ---      ┆ --- ┆ ---                 ┆     ┆ ---     ┆ ---       ┆ ---     ┆ ---       │
# │ i64     ┆ str      ┆ i64 ┆ str                 ┆     ┆ str     ┆ str       ┆ str     ┆ str       │
# ╞═════════╪══════════╪═════╪═════════════════════╪═════╪═════════╪═══════════╪═════════╪═══════════╡
# │ 9       ┆ Distrito ┆ 0   ┆ Total del Distrito  ┆ ... ┆ 1171631 ┆ 1715772   ┆ 1817230 ┆ 936648    │
# │         ┆ Federal  ┆     ┆ Federal             ┆     ┆         ┆           ┆         ┆           │
# │ 9       ┆ Distrito ┆ 2   ┆ Azcapotzalco        ┆ ... ┆ 60003   ┆ 86750     ┆ 88236   ┆ 47225     │
# │         ┆ Federal  ┆     ┆                     ┆     ┆         ┆           ┆         ┆           │
# ...

# %%
censo_nd_df = pl.read_ndjson('../output/censo_nd.json')
censo_nd_df.head()
# Out:
# shape: (5, 198)
# ┌─────────┬──────────┬─────┬─────────────────────┬─────┬─────────┬───────────┬─────────┬───────────┐
# │ ENTIDAD ┆ NOM_ENT  ┆ MUN ┆ NOM_MUN             ┆ ... ┆ VPH_PC  ┆ VPH_TELEF ┆ VPH_CEL ┆ VPH_INTER │
# │ ---     ┆ ---      ┆ --- ┆ ---                 ┆     ┆ ---     ┆ ---       ┆ ---     ┆ ---       │
# │ i64     ┆ str      ┆ i64 ┆ str                 ┆     ┆ str     ┆ str       ┆ str     ┆ str       │
# ╞═════════╪══════════╪═════╪═════════════════════╪═════╪═════════╪═══════════╪═════════╪═══════════╡
# │ 9       ┆ Distrito ┆ 0   ┆ Total del Distrito  ┆ ... ┆ 1171631 ┆ 1715772   ┆ 1817230 ┆ 936648    │
# │         ┆ Federal  ┆     ┆ Federal             ┆     ┆         ┆           ┆         ┆           │
# │ 9       ┆ Distrito ┆ 2   ┆ Azcapotzalco        ┆ ... ┆ 60003   ┆ 86750     ┆ 88236   ┆ 47225     │
# │         ┆ Federal  ┆     ┆                     ┆     ┆         ┆           ┆         ┆           │
# ...

# %%
pl.scan_ndjson('../output/censo_nd.json').select('ENTIDAD').collect().head()
# Out:
# shape: (5, 1)
# ┌─────────┐
# │ ENTIDAD │
# │ ---     │
# │ i64     │
# ╞═════════╡
# │ 9       │
# │ 9       │
# │ 9       │
# │ 9       │
# │ 9       │
# └─────────┘

# %% [markdown]
# 🐻‍❄️ Polars **NO** puede leer JSON anidados por el momento 😭 <br>
# Si es necesario debemos apoyarnos de Pandas 🐼

# %%
import json
with open('../data/nested.json') as data_file:    
    data = json.load(data_file) 
pl.DataFrame(pd.json_normalize(data))
# Out:
# shape: (1, 5)
# ┌─────────┬──────────┬──────────────┬─────────────────────┬───────────────────┐
# │ company ┆ location ┆ info.founder ┆ info.contacts.email ┆ info.contacts.tel │
# │ ---     ┆ ---      ┆ ---          ┆ ---                 ┆ ---               │
# │ str     ┆ str      ┆ str          ┆ str                 ┆ str               │
# ╞═════════╪══════════╪══════════════╪═════════════════════╪═══════════════════╡
# │ Zophia  ┆ Mexico   ┆ Guillermo    ┆ contact@zophia.io   ┆ 9876543210        │
# └─────────┴──────────┴──────────────┴─────────────────────┴───────────────────┘

# %% [markdown]
# ## Lectura de CSVs por batches
# En ocasiones es necesario leer archivos muy grandes y tener problemas de memoria. Para estos casos podemos leer por batches.

# %%
reader = pl.read_csv_batched("../data/inegi.csv", encoding="utf8-lossy")
batches = reader.next_batches(10)
for df in batches:
    print(df)
# Out:
# shape: (22010, 42)
# ┌─────────┬─────────────┬─────────┬──────────┬─────┬──────────┬────────────┬────────────┬──────────┐
# │ id      ┆ clee        ┆ nom_est ┆ raz_soci ┆ ... ┆ tipoUniE ┆ latitud    ┆ longitud   ┆ fecha_al │
# │ ---     ┆ ---         ┆ ab      ┆ al       ┆     ┆ co       ┆ ---        ┆ ---        ┆ ta       │
# │ i64     ┆ str         ┆ ---     ┆ ---      ┆     ┆ ---      ┆ f64        ┆ f64        ┆ ---      │
# │         ┆             ┆ str     ┆ str      ┆     ┆ str      ┆            ┆            ┆ str      │
# ╞═════════╪═════════════╪═════════╪══════════╪═════╪══════════╪════════════╪════════════╪══════════╡
# │ 6174829 ┆ 20169114119 ┆ PESCA   ┆ null     ┆ ... ┆ Fijo     ┆ 18.255652  ┆ -96.614697 ┆ 2010-07  │
# │         ┆ 00100100000 ┆ DE CRUS ┆          ┆     ┆          ┆            ┆            ┆          │
# │         ┆ 0000U7      ┆ T�CEOS, ┆          ┆     ┆          ┆            ┆            ┆          │
# ...

# %% [markdown]
# ## Múltiples archivos 🗄
#
# Nota: Para escribir archivos `csv` con Polars la ruta debe existir previamente

# %%
for file in range(5):
    pl.DataFrame({"col_num": [1,2,3,4,5], "col_str": [None, "A", "A", "B", "B"]}).write_csv(f"../data/csv/archivo_{file}.csv")

# %% [markdown]
# Para leer múltiples archivos podemos usar globbing patterns:

# %%
files = pl.read_csv("../data/csv/archivo_*.csv")
files
# Out:
# shape: (25, 2)
# ┌─────────┬─────────┐
# │ col_num ┆ col_str │
# │ ---     ┆ ---     │
# │ i64     ┆ str     │
# ╞═════════╪═════════╡
# │ 1       ┆ null    │
# │ 2       ┆ A       │
# │ 3       ┆ A       │
# │ 4       ┆ B       │
# │ ...     ┆ ...     │
# │ 2       ┆ A       │
# │ 3       ┆ A       │
# │ 4       ┆ B       │
# │ 5       ┆ B       │
# └─────────┴─────────┘

# %%
pl.scan_csv("../data/csv/archivo_*.csv").describe_plan()
# Out:
# /var/folders/jc/ykm1pg6n2gq03406v_kzy0cm0000gn/T/ipykernel_37231/3093725373.py:1: DeprecationWarning: `LazyFrame.describe_plan` has been deprecated; Please use `LazyFrame.explain` instead
#   pl.scan_csv("../data/csv/archivo_*.csv").describe_plan()
# '  RECHUNK\n    UNION:\n    PLAN 0:\n      CSV SCAN ../data/csv/archivo_0.csv\n      PROJECT */2 COLUMNS\n    PLAN 1:\n      CSV SCAN ../data/csv/archivo_1.csv\n      PROJECT */2 COLUMNS\n    PLAN 2:\n      CSV SCAN ../data/csv/archivo_2.csv\n      PROJECT */2 COLUMNS\n    PLAN 3:\n      CSV SCAN ../data/csv/archivo_3.csv\n      PROJECT */2 COLUMNS\n    PLAN 4:\n      CSV SCAN ../data/csv/archivo_4.csv\n      PROJECT */2 COLUMNS\n    END UNION\n'

# %% [markdown]
# Podemos procesar en paralelo sin tener que unir los dataframes:

# %%
import glob

queries = []
for file in glob.glob("../data/csv/archivo_*.csv"):
    query = pl.scan_csv(file).groupby("col_str").agg([pl.count(), pl.sum("col_num")])
    queries.append(query)

dataframes = pl.collect_all(queries)
dataframes
# Out:
# [shape: (3, 3)
#  ┌─────────┬───────┬─────────┐
#  │ col_str ┆ count ┆ col_num │
#  │ ---     ┆ ---   ┆ ---     │
#  │ str     ┆ u32   ┆ i64     │
#  ╞═════════╪═══════╪═════════╡
#  │ A       ┆ 2     ┆ 5       │
#  │ null    ┆ 1     ┆ 1       │
#  │ B       ┆ 2     ┆ 9       │
#  └─────────┴───────┴─────────┘,
#  shape: (3, 3)
#  ┌─────────┬───────┬─────────┐
#  │ col_str ┆ count ┆ col_num │
#  │ ---     ┆ ---   ┆ ---     │
#  │ str     ┆ u32   ┆ i64     │
#  ╞═════════╪═══════╪═════════╡
#  │ A       ┆ 2     ┆ 5       │
#  │ B       ┆ 2     ┆ 9       │
#  │ null    ┆ 1     ┆ 1       │
#  └─────────┴───────┴─────────┘,
#  shape: (3, 3)
#  ┌─────────┬───────┬─────────┐
#  │ col_str ┆ count ┆ col_num │
#  │ ---     ┆ ---   ┆ ---     │
#  │ str     ┆ u32   ┆ i64     │
#  ╞═════════╪═══════╪═════════╡
#  │ B       ┆ 2     ┆ 9       │
#  │ A       ┆ 2     ┆ 5       │
#  │ null    ┆ 1     ┆ 1       │
#  └─────────┴───────┴─────────┘,
#  shape: (3, 3)
#  ┌─────────┬───────┬─────────┐
# ...

# %% [markdown]
# ## Bases de Datos
#
# El método `read_sql`en Polars nos permite acceder de forma veloz ⚡ a bases de datos. Por detrás usa https://github.com/sfu-db/connector-x

# %%
pl_conn = "postgres://postgres:admin@localhost:5432"
query = "SELECT * FROM empleados"
empleados = pl.read_sql(query, pl_conn)
empleados
# Out:
# shape: (15, 12)
# ┌───────────┬──────────┬───────────┬──────┬─────┬────────────┬────────────┬────────────┬────────────┐
# │ id_emplea ┆ nombre   ┆ apellido  ┆ pais ┆ ... ┆ departamen ┆ descripcio ┆ contrato_p ┆ ultimo_ing │
# │ do        ┆ ---      ┆ ---       ┆ ---  ┆     ┆ to         ┆ n_puesto   ┆ ermanente  ┆ reso       │
# │ ---       ┆ str      ┆ str       ┆ str  ┆     ┆ ---        ┆ ---        ┆ ---        ┆ ---        │
# │ i32       ┆          ┆           ┆      ┆     ┆ str        ┆ str        ┆ bool       ┆ datetime[n │
# │           ┆          ┆           ┆      ┆     ┆            ┆            ┆            ┆ s]         │
# ╞═══════════╪══════════╪═══════════╪══════╪═════╪════════════╪════════════╪════════════╪════════════╡
# │ 1         ┆ Raul     ┆ Martinez  ┆ MX   ┆ ... ┆ Recursos   ┆ Descripcio ┆ true       ┆ 2022-03-01 │
# │           ┆          ┆           ┆      ┆     ┆ Humanos    ┆ n          ┆            ┆ 09:00:15   │
# ...

# %% [markdown]
# Por el momento la escritura a bases de datos directamente con Polars no es posible. Una opción es con psycopg2 pero el código es bastante extenso y complejo:

# %%
from psycopg2 import sql
import psycopg2.extras

# create sql identifiers for the column names
# we do this to safely insert this into a sql query
columns = sql.SQL(",").join(sql.Identifier(name) for name in empleados.columns)

# create placeholders for the values. These will be filled later
values = sql.SQL(",").join([sql.Placeholder() for _ in empleados.columns])

table_id = "empleados"

# prepare the insert query
insert_stmt = sql.SQL("INSERT INTO {} ({}) VALUES({});").format(
    sql.Identifier(table_id), columns, values
)

# make a connection
conn = psycopg2.connect("postgres://postgres:admin@localhost:5432")
cur = conn.cursor()

# do the insert
psycopg2.extras.execute_batch(cur, insert_stmt, empleados.rows())
conn.commit()

# %%
empleados_dup = pl.read_sql(query, pl_conn)
empleados_dup
# Out:
# shape: (30, 12)
# ┌───────────┬──────────┬───────────┬──────┬─────┬────────────┬────────────┬────────────┬────────────┐
# │ id_emplea ┆ nombre   ┆ apellido  ┆ pais ┆ ... ┆ departamen ┆ descripcio ┆ contrato_p ┆ ultimo_ing │
# │ do        ┆ ---      ┆ ---       ┆ ---  ┆     ┆ to         ┆ n_puesto   ┆ ermanente  ┆ reso       │
# │ ---       ┆ str      ┆ str       ┆ str  ┆     ┆ ---        ┆ ---        ┆ ---        ┆ ---        │
# │ i32       ┆          ┆           ┆      ┆     ┆ str        ┆ str        ┆ bool       ┆ datetime[n │
# │           ┆          ┆           ┆      ┆     ┆            ┆            ┆            ┆ s]         │
# ╞═══════════╪══════════╪═══════════╪══════╪═════╪════════════╪════════════╪════════════╪════════════╡
# │ 1         ┆ Raul     ┆ Martinez  ┆ MX   ┆ ... ┆ Recursos   ┆ Descripcio ┆ true       ┆ 2022-03-01 │
# │           ┆          ┆           ┆      ┆     ┆ Humanos    ┆ n          ┆            ┆ 09:00:15   │
# ...

# %%
cur.execute("TRUNCATE empleados")
conn.commit()

# %% [markdown]
# ## De Polars a Pandas y Pandas a Polars 🐻‍❄️ 🐼
#
# Primero usarenmos el dataframe en Polars de empleados para regenerar las filas en la tabla de Postgres. Usamos `to_pandas` para la conversión

# %%
from sqlalchemy import create_engine

db = create_engine("postgresql://postgres:admin@localhost:5432")
empleados.to_pandas().to_sql('empleados', db, if_exists='append', index=False)
# Out:
# 15

# %% [markdown]
# Validamos que los datos estén correctos leyendo desde Pandas y convirtiendo a Polars con `from_pandas`

# %%
conn = psycopg2.connect("postgresql://postgres:admin@localhost:5432")
pl.from_pandas(pd.read_sql(query, conn))
# Out:
# /var/folders/jc/ykm1pg6n2gq03406v_kzy0cm0000gn/T/ipykernel_37231/1953973003.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pl.from_pandas(pd.read_sql(query, conn))
# shape: (15, 12)
# ┌───────────┬──────────┬───────────┬──────┬─────┬────────────┬────────────┬────────────┬────────────┐
# │ id_emplea ┆ nombre   ┆ apellido  ┆ pais ┆ ... ┆ departamen ┆ descripcio ┆ contrato_p ┆ ultimo_ing │
# │ do        ┆ ---      ┆ ---       ┆ ---  ┆     ┆ to         ┆ n_puesto   ┆ ermanente  ┆ reso       │
# │ ---       ┆ str      ┆ str       ┆ str  ┆     ┆ ---        ┆ ---        ┆ ---        ┆ ---        │
# │ i64       ┆          ┆           ┆      ┆     ┆ str        ┆ str        ┆ bool       ┆ datetime[n │
# │           ┆          ┆           ┆      ┆     ┆            ┆            ┆            ┆ s]         │
# ...

# %% [markdown]
# ## Uso de visualizaciones
#
# Podemos usar tanto Pandas como Polars 🐻‍❄️ <br>
# En el caso de Polars debemos hacer uso de `Series`. Esto hace que el código sea más largo <br>
# Para estos ejemplos usaremos `Plotly`. Los mapas requieren una cuenta de Mapbox

# %% [markdown]
# Nos apoyaremos de la potencia de 🐻‍❄️ para las transformaciones pero usamos `to_pandas` debido a que varios métodos de visualización esperan un Dataframe de 🐼

# %%
pd_df = pl.read_parquet("../output/inegi.parquet") \
    .with_columns(
        pl.lit(1).alias("size")
    ) \
    .to_pandas()
pd_df.head()
# Out:
#         id                          clee  \
# 0  6174829  20169114119001001000000000U7
# 1  6174806  20406114119000391000000000U9
# 2  6174723  20406114119000341000000000U4
# 3  6174722  20309114119000781000000000U7
# 4  6174801  20406114119000381000000000U0
#
#                                            nom_estab raz_social  codigo_act  \
# 0  PESCA DE CRUSTÁCEOS, MOLUSCOS Y OTROS PECES SI...       None      114119
# 1  PESCA DE CRUSTÁCEOS, MOLUSCOS Y OTROS PECES SI...       None      114119
# 2  PESCA DE CRUSTÁCEOS, MOLUSCOS Y OTROS PECES SI...       None      114119
# 3  PESCA DE CRUSTÁCEOS, MOLUSCOS Y OTROS PECES SI...       None      114119
# 4  PESCA DE CRUSTÁCEOS, MOLUSCOS Y OTROS PECES SI...       None      114119
#
#                                           nombre_act         per_ocu  \
# 0  Pesca y captura de peces, crustáceos, moluscos...  0 a 5 personas
# 1  Pesca y captura de peces, crustáceos, moluscos...  0 a 5 personas
# ...

# %%
import plotly.express as px
import plotly.io as pio
from dotenv import load_dotenv
import os

pio.renderers.default = "notebook_connected"
load_dotenv()

#Crea tu cuenta y pon el valor de tu token aquí:
px.set_mapbox_access_token(os.getenv("MAPBOX_TOKEN"))


fig = px.scatter_mapbox(
    pd_df,
    lat= "latitud",
    lon= "longitud",
    size = "size", 
    zoom = 10,
    title = "Comercios Agropecuarios en México"
)
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.18.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ...

# %%
df = pl.DataFrame(
     {
         'Model': ['iPhone X','iPhone XS','iPhone 12',
                   'iPhone 13','Samsung S11','Samsung S12',
                   'Mi A1','Mi A2'],
         'Sales': [80,170,130,205,400,30,14,8],     
         'Company': ['Apple','Apple','Apple','Apple',
                     'Samsung','Samsung','Xiao Mi','Xiao Mi'],
     }
)
df
# Out:
# shape: (8, 3)
# ┌─────────────┬───────┬─────────┐
# │ Model       ┆ Sales ┆ Company │
# │ ---         ┆ ---   ┆ ---     │
# │ str         ┆ i64   ┆ str     │
# ╞═════════════╪═══════╪═════════╡
# │ iPhone X    ┆ 80    ┆ Apple   │
# │ iPhone XS   ┆ 170   ┆ Apple   │
# │ iPhone 12   ┆ 130   ┆ Apple   │
# │ iPhone 13   ┆ 205   ┆ Apple   │
# │ Samsung S11 ┆ 400   ┆ Samsung │
# │ Samsung S12 ┆ 30    ┆ Samsung │
# │ Mi A1       ┆ 14    ┆ Xiao Mi │
# │ Mi A2       ┆ 8     ┆ Xiao Mi │
# └─────────────┴───────┴─────────┘

# %%
px.bar(x = df.select('Model').to_series(), 
       y = df.select('Sales').to_series())
# Out:
# <div>                            <div id="37dca49c-ff3a-4c8d-a1b9-f3764b59f6a8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("37dca49c-ff3a-4c8d-a1b9-f3764b59f6a8")) {                    Plotly.newPlot(                        "37dca49c-ff3a-4c8d-a1b9-f3764b59f6a8",                        [{"alignmentgroup":"True","hovertemplate":"x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["iPhone X","iPhone XS","iPhone 12","iPhone 13","Samsung S11","Samsung S12","Mi A1","Mi A2"],"xaxis":"x","y":[80,170,130,205,400,30,14,8],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{
# ...

# %%
px.pie(df,                                   
       names = df.select('Model').to_series(),
       values = df.select('Sales').to_series(), 
       hover_name = df.select('Model').to_series(),
       color_discrete_sequence= px.colors.sequential.Plasma_r)
# Out:
# <div>                            <div id="afc3e116-1f4b-46d6-8912-74aa75d75695" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("afc3e116-1f4b-46d6-8912-74aa75d75695")) {                    Plotly.newPlot(                        "afc3e116-1f4b-46d6-8912-74aa75d75695",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"<b>%{hovertext}</b><br><br>label=%{label}<br>value=%{value}<extra></extra>","hovertext":["iPhone X","iPhone XS","iPhone 12","iPhone 13","Samsung S11","Samsung S12","Mi A1","Mi A2"],"labels":["iPhone X","iPhone XS","iPhone 12","iPhone 13","Samsung S11","Samsung S12","Mi A1","Mi A2"],"legendgroup":"","name":"","showlegend":true,"values":[80,170,130,205,400,30,14,8],"type":"pie"}],                        {"tem
# ...

# %% [markdown]
# ## Cloud
#
# Polars 🐻‍❄️ puede acceder de manera eficiente a Cloud Storage gracias a Arrow 🏹 . Es necesario tener los privilegios y cuentas necesarios, sólo mostraremos la sintaxis del código.

# %% [markdown]
# ### AWS
# AWS tiene un SDK para Pandas que se puede usar para pasar los datoa a Polars: https://aws-sdk-pandas.readthedocs.io/en/stable/
#
# #### S3

# %%
import s3fs

fs = s3fs.S3FileSystem()
bucket = "<YOUR_BUCKET>"
path = "<YOUR_PATH>"

dataset = pq.ParquetDataset(f"s3://{bucket}/{path}", filesystem=fs)
df = pl.from_arrow(dataset.read())

# %% [markdown]
# ### Azure Blob

# %%
from adlfs import AzureBlobFileSystem

abfs = AzureBlobFileSystem(account_name="XXXX", account_key="XXXX", container_name="XXXX")
df = pl.from_arrow(pq.read_table("file.parquet", filesystem=abfs))

# %% [markdown]
# ### Google Cloud

# %%
from datetime import timedelta
from pyarrow import fs

gcs = fs.GcsFileSystem(anonymous=True, retry_time_limit=timedelta(seconds=15))
df = pl.scan_ds(pq.ParquetDataset("gs://bucket/file.parquet", filesystem=gcs))

# %% [markdown]
# ### BigQuery

# %%
from google.cloud import bigquery

client = bigquery.Client()

query = (
    'SELECT name FROM `bigquery-public-data.usa_names.usa_1910_2013` '
    'WHERE state = "TX" '
    'LIMIT 100')
query_job = client.query(query)  # API request
rows = query_job.result()

df = pl.from_arrow(rows.to_arrow())

# %% [markdown]
# ## Ejercicios
#
# 1. Mediante el uso de glob, lee los parquets del dataset de taxi del año 2017.
# 2. Escribe un Parquet particionado por dos columnas del dataset del Censo.
# 3. Carga un dataframe a Polars. Aplica un conjunto de operaciones que consideres que no se podrían hacer fácilmente en Pandas.
# 4. Investiga como puedes leer un dataset de Arrow directamente en Pandas. Compara el performance con Polars.
# 5. Con cualquier dataframe obtén las siguientes visualizaciones con Matplotlib:
#     1. Stacked Bar Chart
#     2. Scatter Plot
# 6. Opcional: Carga datos a Polars de alguna base de datos o de alguna cuenta de AWS, Azure o GCP.
